# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# %%
img = mpimg.imread('I_V_curve.png')
imgplot = plt.imshow(img)
plt.show()

# %%
im = Image.open('I_V_curve.png')
pix = im.load()

# %%
a = np.asarray(im)[:, :, :3]
a.shape
# Out:
# (698, 929, 3)

# %%
temp = a[a.nonzero()[:2]]
temp[np.where((temp != 33) & (temp != 56))[0]]
